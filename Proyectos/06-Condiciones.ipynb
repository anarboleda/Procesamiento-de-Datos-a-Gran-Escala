# %%
# 06. Condiciones en Python
# Ana Sofía Arboleda
# Procesamiento de Datos a Gran Escala
ID: 14264

# %% [markdown]
# ## Concepto de condiciones

# %% [markdown]
# "Situación o circunstancia indispensable para la existencia de otra."
#
# *-Real Academia Española. (2014). Diccionario de la lengua española (23ª ed.)*

# %% [markdown]
# "Condición, que sirve para bifurcar el flujo de control del programa por un camino u otro depen‐
# diendo del valor de una expresión lógica."
#
# *-Pérez, R. (2026). Programación estructurada*

# %% [markdown]
# "Una condición es una expresión que se evalúa a verdadero o falso."
#
# *-Badenas, J & llopis, J.(2001). Curso práctico de programación en C y C++*

# %% [markdown]
# **Referencias:**
#
# -Pérez, R. (2026). *Programación estructurada*
#
# -Badenas, J & llopis,J.(2001). *Curso práctico de programación en C y C++*
#
# -Real Academia Española. (2014). *Diccionario de la lengua española* (23ª ed.)

# %% [markdown]
# ## Ejemplo de sintaxis de condiciones

# %%
edad = 18

if edad >= 18:
    print("Es mayor de edad")
# Out:
# Es mayor de edad

# %% [markdown]
# **Ideas clave**
#
# -Permiten tomar decisiones en el programa.
#
# -Evalúan expresiones booleanas.
#
# -Ejecutan bloques de código según la condición.

# %% [markdown]
# ## Ejecución de actividades
#
# > En esta sección se desarrollarán los ejercicios propuestos en clase
# relacionados con el uso de condiciones en Python.

# %% [markdown]
# ## Documentación de instrucciones y algoritmos
#
# > Aquí se documentarán las instrucciones utilizadas y los algoritmos
# implementados para la resolución de los ejercicios del taller.

# %% [markdown]
# ## Conclusiones
#
# > En esta sección se presentarán las conclusiones obtenidas tras el desarrollo
# de las actividades del cuaderno.
