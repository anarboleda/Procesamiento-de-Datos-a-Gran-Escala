# %%
# 09. Clases en Python
# Ana Sofía Arboleda
# Procesamiento de Datos a Gran Escala
# ID: 14264

# %% [markdown]
# ## Concepto de clases

# %% [markdown]
# "Una clase es la plantilla o concepto genérico de un objeto, que
# se usa para definir sus propiedades y servicios. Un objeto es pues una instancia
# concreta de una clase."
#
# *-Rodó, D. (2023). El lenguaje Python*

# %% [markdown]
# "También podemos darnos cuenta de que, aunque todos los objetos tienen propiedades distintas, como el color del cabello, el grado de simpatía o el peso, todos tienen un conjunto de atributos en común por ser ejemplos de una entidad superior llamada “ser humano”. A este patrón de objetos (en nuestro caso “ser humano”) lo llamaremos clase."
#
# *-Izquierdo, L. (2007). Introducción a la Programación Orientada a Objetos*

# %% [markdown]
# **Referencias:**
#
# -Rodó, D. (2023). *El lenguaje Python*
# -Izquierdo, L. (2007). *Introducción a la Programación Orientada a Objetos*

# %% [markdown]
# ## Ejemplo de sintaxis de clases

# %%
class Persona:
    def __init__(self, nombre):
        self.nombre = nombre

# %% [markdown]
# **Ideas clave**
#
# -Permiten crear objetos.
#
# -Agrupan datos y comportamientos.
#
# -Son base de la programación orientada a objetos.

# %% [markdown]
# ## Ejecución de actividades
#
# > En esta sección se desarrollarán los ejercicios propuestos en clase
# relacionados con el uso de clases en Python.

# %% [markdown]
# ## Documentación de instrucciones y algoritmos
#
# > Aquí se documentarán las instrucciones utilizadas y los algoritmos
# implementados para la resolución de los ejercicios del taller.

# %% [markdown]
# ## Conclusiones
#
# > En esta sección se presentarán las conclusiones obtenidas tras el desarrollo
# de las actividades del cuaderno.
