# %%
# 09. Clases en Python
# Ana Sofía Arboleda
# Procesamiento de Datos a Gran Escala
# ID: 14264

# %% [markdown]
# ## Concepto de clases

# %% [markdown]
# "Una clase es la plantilla o concepto genérico de un objeto, que
# se usa para definir sus propiedades y servicios. Un objeto es pues una instancia
# concreta de una clase."
#
# *-Rodó, D. (2023). El lenguaje Python*

# %% [markdown]
# "También podemos darnos cuenta de que, aunque todos los objetos tienen propiedades distintas, como el color del cabello, el grado de simpatía o el peso, todos tienen un conjunto de atributos en común por ser ejemplos de una entidad superior llamada “ser humano”. A este patrón de objetos (en nuestro caso “ser humano”) lo llamaremos clase."
#
# *-Izquierdo, L. (2007). Introducción a la Programación Orientada a Objetos*

# %% [markdown]
# **Referencias:**
#
# -Rodó, D. (2023). *El lenguaje Python*
# -Izquierdo, L. (2007). *Introducción a la Programación Orientada a Objetos*

# %% [markdown]
# ## Ejemplo de sintaxis de clases

# %%
class Persona:
    def __init__(self, nombre):
        self.nombre = nombre

# %% [markdown]
# **Ideas clave**
#
# -Permiten crear objetos.
#
# -Agrupan datos y comportamientos.
#
# -Son base de la programación orientada a objetos.

# %% [markdown]
# ## Ejecución de actividades
#
# > En esta sección se desarrollarán los ejercicios propuestos en clase
# relacionados con el uso de clases en Python.

# %% [markdown]
# 1. Cree una clase llamada <code>Persona</code> que tenga como atributos nombre y edad. Posteriormente, cree un objeto de esta clase y muestre los valores almacenados en sus atributos.

# %%
# Respuesta =
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

persona1 = Persona("Sofía", 21)

print(persona1.nombre)
print(persona1.edad)

# %% [markdown]
# 2. Modifique la clase <code>Persona</code> para que incluya un método llamado <code>saludar()</code> que muestre un mensaje con el nombre y la edad de la persona. Cree un objeto y ejecute el método.

# %%
# Respuesta = 
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def saludar(self):
        print(f"Hola, mi nombre es {self.nombre} y tengo {self.edad} años")

persona1 = Persona("Ana", 30)
persona1.saludar()

# %% [markdown]
# 3. Cree una clase <code>Estudiante</code> que tenga como atributos nombre y notas (lista). Implemente un método que calcule el promedio de las notas del estudiante.

# %%
# Respuesta =
class Estudiante:
    def __init__(self, nombre, notas):
        self.nombre = nombre
        self.notas = notas

    def promedio(self):
        return sum(self.notas) / len(self.notas)

estudiante = Estudiante("Sofia", [4.0, 3.5, 4.5])
print(estudiante.promedio())

# %% [markdown]
# ## Documentación de instrucciones y algoritmos
#
# > Aquí se documentarán las instrucciones utilizadas y los algoritmos
# implementados para la resolución de los ejercicios del taller.

# %% [markdown]
# 1. **Definición de una clase básica con método**
#
# - **Instrucciones :** class Saludo, def __init__(self, nombre), def saludar(self), print()
#
# - **Algoritmo :**
#
#     1) Definir una clase que represente una entidad genérica.
#     2) Crear un constructor que reciba un atributo inicial.
#     3) Almacenar el atributo usando self.
#     4) Implementar un método que utilice el atributo para mostrar un mensaje.
#     5) Crear una instancia de la clase y ejecutar el método definido.
#
# 2. **Creación de clase Persona con atributos**
#
# - **Instrucciones :** class Persona, __init__(self, nombre, edad, correo), creación de objeto, print()
#
# - **Algoritmo :**
#
#     1) Definir una clase llamada Persona.
#     2) Declarar un constructor que reciba nombre, edad y correo.
#     3) Asignar los valores a los atributos del objeto mediante self.
#     4) Instanciar un objeto de tipo Persona.
#     5) Acceder a los atributos del objeto y mostrarlos por consola.
#
# 3. **Manejo de listas como atributos (Estudiante y notas)**
#
# - **Instrucciones :** class Estudiante, notas = [], sum(), len(), método promedio()
#
# - **Algoritmo :**
#
#     1) Definir una clase que incluya una lista como atributo.
#     2) Inicializar la lista en el constructor.
#     3) Crear un método que procese los datos de la lista.
#     4) Calcular la suma de los valores usando sum().
#     5) Calcular la cantidad de elementos con len().
#     6) Retornar el resultado del cálculo promedio.
#
# 4. **Invocación de métodos de una clase**
#
# - **Instrucciones :** Creación de objeto, llamada a método: objeto.metodo()
#
# - **Algoritmo :**
#
#     1) Crear una instancia de la clase definida.
#     2) Almacenar la instancia en una variable.
#     3) Llamar al método usando la notación punto.
#     4) Ejecutar el método y obtener el resultado correspondiente.

# %% [markdown]
# ## Conclusiones
#
# > En esta sección se presentarán las conclusiones obtenidas tras el desarrollo
# de las actividades del cuaderno.

# %% [markdown]
# Las clases en Python constituyen la base de la programación orientada a objetos, permitiendo modelar entidades del mundo real mediante estructuras organizadas que combinan datos y comportamiento. A lo largo del cuaderno se abordaron conceptos fundamentales como la definición de clases, el uso del método constructor __init__, la creación de atributos, la implementación de métodos y la instanciación de objetos. Estos elementos facilitan la reutilización del código, mejoran la legibilidad y permiten que los programas sean más escalables y mantenibles. Los ejercicios desarrollados demuestran cómo las clases pueden aplicarse en diferentes contextos como personas, cuentas bancarias, productos y estudiantes, incorporando validaciones, cálculos y modificaciones de estado. En conjunto, el uso de clases promueve una estructura lógica y modular del código, fortaleciendo las buenas prácticas de desarrollo y preparando al programador para la construcción de aplicaciones más complejas.
